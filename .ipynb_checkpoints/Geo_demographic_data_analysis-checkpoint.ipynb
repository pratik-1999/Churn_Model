# %%
import numpy as np
import csv
from collections import defaultdict

# %%
path = './Churn_Modelling.csv'
file = open(path, 'r')

# %%
data = csv.reader(file, delimiter = '\t')

# %%
dataset = list(data)

# %%
dataset = [d[0].split(',') for d in dataset]

# %%
dataset[2]
# Out:
# ['2',
#  '15647311',
#  'Hill',
#  '608',
#  'Spain',
#  'Female',
#  '41',
#  '1',
#  '83807.86',
#  '1',
#  '0',
#  '1',
#  '112542.58',
#  '0']

# %%
header = dataset[0]
dataset = dataset[1:]

# %%
header
# Out:
# ['RowNumber',
#  'CustomerId',
#  'Surname',
#  'CreditScore',
#  'Geography',
#  'Gender',
#  'Age',
#  'Tenure',
#  'Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'EstimatedSalary',
#  'Exited']

# %%
dat = []
for d in dataset:
    di = dict(zip(header, d))
    di['CustomerId'] = int(d[1])
    di['CreditScore'] = int(d[3])
    di['Geography'] = d[4]
    di['Gender'] = d[5]
    di['Age'] = int(d[6])
    di['Tenure'] = int(d[7])
    di['Balance'] = float(d[8])
    di['IsActiveMember'] = int(d[-3])
    di['EstimatedSalary'] = float(d[-2])
    di['Exited'] = int(d[-1])
    di.pop('RowNumber')
    di.pop('Surname')
    di.pop('NumOfProducts')
    di.pop('HasCrCard')
    
    
    dat.append(di)

# %%
dat
# Out:
# [{'CustomerId': 15634602,
#   'CreditScore': 619,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 42,
#   'Tenure': 2,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 101348.88,
#   'Exited': 1},
#  {'CustomerId': 15647311,
#   'CreditScore': 608,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 41,
#   'Tenure': 1,
#   'Balance': 83807.86,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 112542.58,
#   'Exited': 0},
#  {'CustomerId': 15619304,
#   'CreditScore': 502,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 42,
#   'Tenure': 8,
#   'Balance': 159660.8,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 113931.57,
#   'Exited': 1},
#  {'CustomerId': 15701354,
#   'CreditScore': 699,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 39,
#   'Tenure': 1,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 93826.63,
#   'Exited': 0},
#  {'CustomerId': 15737888,
#   'CreditScore': 850,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 43,
#   'Tenure': 2,
#   'Balance': 125510.82,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 79084.1,
#   'Exited': 0},
#  {'CustomerId': 15574012,
#   'CreditScore': 645,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 44,
#   'Tenure': 8,
#   'Balance': 113755.78,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 149756.71,
#   'Exited': 1},
#  {'CustomerId': 15592531,
#   'CreditScore': 822,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 50,
#   'Tenure': 7,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 10062.8,
#   'Exited': 0},
#  {'CustomerId': 15656148,
#   'CreditScore': 376,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 29,
#   'Tenure': 4,
#   'Balance': 115046.74,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 119346.88,
#   'Exited': 1},
#  {'CustomerId': 15792365,
#   'CreditScore': 501,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 44,
#   'Tenure': 4,
#   'Balance': 142051.07,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 74940.5,
#   'Exited': 0},
#  {'CustomerId': 15592389,
#   'CreditScore': 684,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 27,
#   'Tenure': 2,
#   'Balance': 134603.88,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 71725.73,
#   'Exited': 0},
#  {'CustomerId': 15767821,
#   'CreditScore': 528,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 31,
#   'Tenure': 6,
#   'Balance': 102016.72,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 80181.12,
#   'Exited': 0},
#  {'CustomerId': 15737173,
#   'CreditScore': 497,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 24,
#   'Tenure': 3,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 76390.01,
#   'Exited': 0},
#  {'CustomerId': 15632264,
#   'CreditScore': 476,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 34,
#   'Tenure': 10,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 26260.98,
#   'Exited': 0},
#  {'CustomerId': 15691483,
#   'CreditScore': 549,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 25,
#   'Tenure': 5,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 190857.79,
#   'Exited': 0},
#  {'CustomerId': 15600882,
#   'CreditScore': 635,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 35,
#   'Tenure': 7,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 65951.65,
#   'Exited': 0},
#  {'CustomerId': 15643966,
#   'CreditScore': 616,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 45,
#   'Tenure': 3,
#   'Balance': 143129.41,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 64327.26,
#   'Exited': 0},
#  {'CustomerId': 15737452,
#   'CreditScore': 653,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 58,
#   'Tenure': 1,
#   'Balance': 132602.88,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 5097.67,
#   'Exited': 1},
#  {'CustomerId': 15788218,
#   'CreditScore': 549,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 24,
#   'Tenure': 9,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 14406.41,
#   'Exited': 0},
#  {'CustomerId': 15661507,
#   'CreditScore': 587,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 45,
#   'Tenure': 6,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 158684.81,
#   'Exited': 0},
#  {'CustomerId': 15568982,
#   'CreditScore': 726,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 24,
#   'Tenure': 6,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 54724.03,
#   'Exited': 0},
#  {'CustomerId': 15577657,
#   'CreditScore': 732,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 41,
#   'Tenure': 8,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 170886.17,
#   'Exited': 0},
#  {'CustomerId': 15597945,
#   'CreditScore': 636,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 32,
#   'Tenure': 8,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 138555.46,
#   'Exited': 0},
#  {'CustomerId': 15699309,
#   'CreditScore': 510,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 38,
#   'Tenure': 4,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 118913.53,
#   'Exited': 1},
#  {'CustomerId': 15725737,
#   'CreditScore': 669,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 46,
#   'Tenure': 3,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 8487.75,
#   'Exited': 0},
#  {'CustomerId': 15625047,
#   'CreditScore': 846,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 38,
#   'Tenure': 5,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 187616.16,
#   'Exited': 0},
#  {'CustomerId': 15738191,
#   'CreditScore': 577,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 25,
#   'Tenure': 3,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 124508.29,
#   'Exited': 0},
#  {'CustomerId': 15736816,
#   'CreditScore': 756,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 36,
#   'Tenure': 2,
#   'Balance': 136815.64,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 170041.95,
#   'Exited': 0},
#  {'CustomerId': 15700772,
#   'CreditScore': 571,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 44,
#   'Tenure': 9,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 38433.35,
#   'Exited': 0},
#  {'CustomerId': 15728693,
#   'CreditScore': 574,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 43,
#   'Tenure': 3,
#   'Balance': 141349.43,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 100187.43,
#   'Exited': 0},
#  {'CustomerId': 15656300,
#   'CreditScore': 411,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 29,
#   'Tenure': 0,
#   'Balance': 59697.17,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 53483.21,
#   'Exited': 0},
#  {'CustomerId': 15589475,
#   'CreditScore': 591,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 39,
#   'Tenure': 3,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 140469.38,
#   'Exited': 1},
#  {'CustomerId': 15706552,
#   'CreditScore': 533,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 36,
#   'Tenure': 7,
#   'Balance': 85311.7,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 156731.91,
#   'Exited': 0},
#  {'CustomerId': 15750181,
#   'CreditScore': 553,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 41,
#   'Tenure': 9,
#   'Balance': 110112.54,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 81898.81,
#   'Exited': 0},
#  {'CustomerId': 15659428,
#   'CreditScore': 520,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 42,
#   'Tenure': 6,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 34410.55,
#   'Exited': 0},
#  {'CustomerId': 15732963,
#   'CreditScore': 722,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 29,
#   'Tenure': 9,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 142033.07,
#   'Exited': 0},
#  {'CustomerId': 15794171,
#   'CreditScore': 475,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 45,
#   'Tenure': 0,
#   'Balance': 134264.04,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 27822.99,
#   'Exited': 1},
#  {'CustomerId': 15788448,
#   'CreditScore': 490,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 31,
#   'Tenure': 3,
#   'Balance': 145260.23,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 114066.77,
#   'Exited': 0},
#  {'CustomerId': 15729599,
#   'CreditScore': 804,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 33,
#   'Tenure': 7,
#   'Balance': 76548.6,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 98453.45,
#   'Exited': 0},
#  {'CustomerId': 15717426,
#   'CreditScore': 850,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 36,
#   'Tenure': 7,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 40812.9,
#   'Exited': 0},
#  {'CustomerId': 15585768,
#   'CreditScore': 582,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 41,
#   'Tenure': 6,
#   'Balance': 70349.48,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 178074.04,
#   'Exited': 0},
#  {'CustomerId': 15619360,
#   'CreditScore': 472,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 40,
#   'Tenure': 4,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 70154.22,
#   'Exited': 0},
#  {'CustomerId': 15738148,
#   'CreditScore': 465,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 51,
#   'Tenure': 8,
#   'Balance': 122522.32,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 181297.65,
#   'Exited': 1},
#  {'CustomerId': 15687946,
#   'CreditScore': 556,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 61,
#   'Tenure': 2,
#   'Balance': 117419.35,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 94153.83,
#   'Exited': 0},
#  {'CustomerId': 15755196,
#   'CreditScore': 834,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 49,
#   'Tenure': 2,
#   'Balance': 131394.56,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 194365.76,
#   'Exited': 1},
#  {'CustomerId': 15684171,
#   'CreditScore': 660,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 61,
#   'Tenure': 5,
#   'Balance': 155931.11,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 158338.39,
#   'Exited': 0},
#  {'CustomerId': 15754849,
#   'CreditScore': 776,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 32,
#   'Tenure': 4,
#   'Balance': 109421.13,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 126517.46,
#   'Exited': 0},
#  {'CustomerId': 15602280,
#   'CreditScore': 829,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 27,
#   'Tenure': 9,
#   'Balance': 112045.67,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 119708.21,
#   'Exited': 1},
#  {'CustomerId': 15771573,
#   'CreditScore': 637,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 39,
#   'Tenure': 9,
#   'Balance': 137843.8,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 117622.8,
#   'Exited': 1},
#  {'CustomerId': 15766205,
#   'CreditScore': 550,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 38,
#   'Tenure': 2,
#   'Balance': 103391.38,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 90878.13,
#   'Exited': 0},
#  {'CustomerId': 15771873,
#   'CreditScore': 776,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 37,
#   'Tenure': 2,
#   'Balance': 103769.22,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 194099.12,
#   'Exited': 0},
#  {'CustomerId': 15616550,
#   'CreditScore': 698,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 44,
#   'Tenure': 10,
#   'Balance': 116363.37,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 198059.16,
#   'Exited': 0},
#  {'CustomerId': 15768193,
#   'CreditScore': 585,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 36,
#   'Tenure': 5,
#   'Balance': 146050.97,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 86424.57,
#   'Exited': 0},
#  {'CustomerId': 15683553,
#   'CreditScore': 788,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 33,
#   'Tenure': 5,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 116978.19,
#   'Exited': 0},
#  {'CustomerId': 15702298,
#   'CreditScore': 655,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 41,
#   'Tenure': 8,
#   'Balance': 125561.97,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 164040.94,
#   'Exited': 1},
#  {'CustomerId': 15569590,
#   'CreditScore': 601,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 42,
#   'Tenure': 1,
#   'Balance': 98495.72,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 40014.76,
#   'Exited': 1},
#  {'CustomerId': 15760861,
#   'CreditScore': 619,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 43,
#   'Tenure': 1,
#   'Balance': 125211.92,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 113410.49,
#   'Exited': 0},
#  {'CustomerId': 15630053,
#   'CreditScore': 656,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 45,
#   'Tenure': 5,
#   'Balance': 127864.4,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 87107.57,
#   'Exited': 0},
#  {'CustomerId': 15647091,
#   'CreditScore': 725,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 19,
#   'Tenure': 0,
#   'Balance': 75888.2,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 45613.75,
#   'Exited': 0},
#  {'CustomerId': 15623944,
#   'CreditScore': 511,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 66,
#   'Tenure': 4,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 1643.11,
#   'Exited': 1},
#  {'CustomerId': 15804771,
#   'CreditScore': 614,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 51,
#   'Tenure': 4,
#   'Balance': 40685.92,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 46775.28,
#   'Exited': 0},
#  {'CustomerId': 15651280,
#   'CreditScore': 742,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 35,
#   'Tenure': 5,
#   'Balance': 136857.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 84509.57,
#   'Exited': 0},
#  {'CustomerId': 15773469,
#   'CreditScore': 687,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 27,
#   'Tenure': 9,
#   'Balance': 152328.88,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 126494.82,
#   'Exited': 0},
#  {'CustomerId': 15702014,
#   'CreditScore': 555,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 33,
#   'Tenure': 1,
#   'Balance': 56084.69,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 178798.13,
#   'Exited': 0},
#  {'CustomerId': 15751208,
#   'CreditScore': 684,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 56,
#   'Tenure': 8,
#   'Balance': 78707.16,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 99398.36,
#   'Exited': 0},
#  {'CustomerId': 15592461,
#   'CreditScore': 603,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 26,
#   'Tenure': 4,
#   'Balance': 109166.37,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 92840.67,
#   'Exited': 0},
#  {'CustomerId': 15789484,
#   'CreditScore': 751,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 36,
#   'Tenure': 6,
#   'Balance': 169831.46,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 27758.36,
#   'Exited': 0},
#  {'CustomerId': 15696061,
#   'CreditScore': 581,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 34,
#   'Tenure': 1,
#   'Balance': 101633.04,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 110431.51,
#   'Exited': 0},
#  {'CustomerId': 15641582,
#   'CreditScore': 735,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 43,
#   'Tenure': 10,
#   'Balance': 123180.01,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 196673.28,
#   'Exited': 0},
#  {'CustomerId': 15638424,
#   'CreditScore': 661,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 35,
#   'Tenure': 5,
#   'Balance': 150725.53,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 113656.85,
#   'Exited': 0},
#  {'CustomerId': 15755648,
#   'CreditScore': 675,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 21,
#   'Tenure': 8,
#   'Balance': 98373.26,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 18203.0,
#   'Exited': 0},
#  {'CustomerId': 15703793,
#   'CreditScore': 738,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 58,
#   'Tenure': 2,
#   'Balance': 133745.44,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 28373.86,
#   'Exited': 1},
#  {'CustomerId': 15620344,
#   'CreditScore': 813,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 29,
#   'Tenure': 6,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 33953.87,
#   'Exited': 0},
#  {'CustomerId': 15812518,
#   'CreditScore': 657,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 37,
#   'Tenure': 0,
#   'Balance': 163607.18,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 44203.55,
#   'Exited': 0},
#  {'CustomerId': 15779052,
#   'CreditScore': 604,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 25,
#   'Tenure': 5,
#   'Balance': 157780.84,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 58426.81,
#   'Exited': 0},
#  {'CustomerId': 15770811,
#   'CreditScore': 519,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 36,
#   'Tenure': 9,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 145562.4,
#   'Exited': 0},
#  {'CustomerId': 15780961,
#   'CreditScore': 735,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 21,
#   'Tenure': 1,
#   'Balance': 178718.19,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 22388.0,
#   'Exited': 0},
#  {'CustomerId': 15614049,
#   'CreditScore': 664,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 55,
#   'Tenure': 8,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 139161.64,
#   'Exited': 0},
#  {'CustomerId': 15662085,
#   'CreditScore': 678,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 32,
#   'Tenure': 9,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 148210.64,
#   'Exited': 0},
#  {'CustomerId': 15575185,
#   'CreditScore': 757,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 33,
#   'Tenure': 5,
#   'Balance': 77253.22,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 194239.63,
#   'Exited': 0},
#  {'CustomerId': 15803136,
#   'CreditScore': 416,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 41,
#   'Tenure': 10,
#   'Balance': 122189.66,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 98301.61,
#   'Exited': 0},
#  {'CustomerId': 15706021,
#   'CreditScore': 665,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 34,
#   'Tenure': 1,
#   'Balance': 96645.54,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 171413.66,
#   'Exited': 0},
#  {'CustomerId': 15663706,
#   'CreditScore': 777,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 32,
#   'Tenure': 2,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 136458.19,
#   'Exited': 1},
#  {'CustomerId': 15641732,
#   'CreditScore': 543,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 36,
#   'Tenure': 3,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 26019.59,
#   'Exited': 0},
#  {'CustomerId': 15701164,
#   'CreditScore': 506,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 34,
#   'Tenure': 4,
#   'Balance': 90307.62,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 159235.29,
#   'Exited': 0},
#  {'CustomerId': 15738751,
#   'CreditScore': 493,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 46,
#   'Tenure': 4,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 1907.66,
#   'Exited': 0},
#  {'CustomerId': 15805254,
#   'CreditScore': 652,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 75,
#   'Tenure': 10,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 114675.75,
#   'Exited': 0},
#  {'CustomerId': 15762418,
#   'CreditScore': 750,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 22,
#   'Tenure': 3,
#   'Balance': 121681.82,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 128643.35,
#   'Exited': 1},
#  {'CustomerId': 15625759,
#   'CreditScore': 729,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 30,
#   'Tenure': 9,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 151869.35,
#   'Exited': 0},
#  {'CustomerId': 15622897,
#   'CreditScore': 646,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 46,
#   'Tenure': 4,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 93251.42,
#   'Exited': 1},
#  {'CustomerId': 15767954,
#   'CreditScore': 635,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 28,
#   'Tenure': 3,
#   'Balance': 81623.67,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 156791.36,
#   'Exited': 0},
#  {'CustomerId': 15757535,
#   'CreditScore': 647,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 44,
#   'Tenure': 5,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 174205.22,
#   'Exited': 1},
#  {'CustomerId': 15731511,
#   'CreditScore': 808,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 45,
#   'Tenure': 7,
#   'Balance': 118626.55,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 147132.46,
#   'Exited': 0},
#  {'CustomerId': 15809248,
#   'CreditScore': 524,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 36,
#   'Tenure': 10,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 109614.57,
#   'Exited': 0},
#  {'CustomerId': 15640635,
#   'CreditScore': 769,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 29,
#   'Tenure': 8,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 172290.61,
#   'Exited': 0},
#  {'CustomerId': 15676966,
#   'CreditScore': 730,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 42,
#   'Tenure': 4,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 85982.47,
#   'Exited': 0},
#  {'CustomerId': 15699461,
#   'CreditScore': 515,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 35,
#   'Tenure': 10,
#   'Balance': 176273.95,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 121277.78,
#   'Exited': 0},
#  {'CustomerId': 15738721,
#   'CreditScore': 773,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 41,
#   'Tenure': 9,
#   'Balance': 102827.44,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 64595.25,
#   'Exited': 0},
#  {'CustomerId': 15693683,
#   'CreditScore': 814,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 29,
#   'Tenure': 8,
#   'Balance': 97086.4,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 197276.13,
#   'Exited': 0},
#  {'CustomerId': 15604348,
#   'CreditScore': 710,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 22,
#   'Tenure': 8,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 99645.04,
#   'Exited': 0},
#  {'CustomerId': 15633059,
#   'CreditScore': 413,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 34,
#   'Tenure': 9,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 6534.18,
#   'Exited': 0},
#  {'CustomerId': 15808582,
#   'CreditScore': 665,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 40,
#   'Tenure': 6,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 161848.03,
#   'Exited': 0},
#  {'CustomerId': 15743192,
#   'CreditScore': 623,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 44,
#   'Tenure': 6,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 167162.43,
#   'Exited': 0},
#  {'CustomerId': 15580146,
#   'CreditScore': 738,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 31,
#   'Tenure': 9,
#   'Balance': 82674.15,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 41970.72,
#   'Exited': 0},
#  {'CustomerId': 15776605,
#   'CreditScore': 528,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 36,
#   'Tenure': 7,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 60536.56,
#   'Exited': 0},
#  {'CustomerId': 15804919,
#   'CreditScore': 670,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 65,
#   'Tenure': 1,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 177655.68,
#   'Exited': 1},
#  {'CustomerId': 15613854,
#   'CreditScore': 622,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 46,
#   'Tenure': 4,
#   'Balance': 107073.27,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 30984.59,
#   'Exited': 1},
#  {'CustomerId': 15599195,
#   'CreditScore': 582,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 32,
#   'Tenure': 1,
#   'Balance': 88938.62,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 10054.53,
#   'Exited': 0},
#  {'CustomerId': 15812878,
#   'CreditScore': 785,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 36,
#   'Tenure': 2,
#   'Balance': 99806.85,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 36976.52,
#   'Exited': 0},
#  {'CustomerId': 15602312,
#   'CreditScore': 605,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 33,
#   'Tenure': 5,
#   'Balance': 150092.8,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 71862.79,
#   'Exited': 0},
#  {'CustomerId': 15744689,
#   'CreditScore': 479,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 35,
#   'Tenure': 9,
#   'Balance': 92833.89,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 99449.86,
#   'Exited': 1},
#  {'CustomerId': 15803526,
#   'CreditScore': 685,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 30,
#   'Tenure': 3,
#   'Balance': 90536.81,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 63082.88,
#   'Exited': 0},
#  {'CustomerId': 15665790,
#   'CreditScore': 538,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 39,
#   'Tenure': 7,
#   'Balance': 108055.1,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 27231.26,
#   'Exited': 0},
#  {'CustomerId': 15715951,
#   'CreditScore': 562,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 42,
#   'Tenure': 2,
#   'Balance': 100238.35,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 86797.41,
#   'Exited': 0},
#  {'CustomerId': 15591100,
#   'CreditScore': 675,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 36,
#   'Tenure': 9,
#   'Balance': 106190.55,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 22994.32,
#   'Exited': 0},
#  {'CustomerId': 15609618,
#   'CreditScore': 721,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 28,
#   'Tenure': 9,
#   'Balance': 154475.54,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 101300.94,
#   'Exited': 1},
#  {'CustomerId': 15675522,
#   'CreditScore': 628,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 30,
#   'Tenure': 9,
#   'Balance': 132351.29,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 74169.13,
#   'Exited': 0},
#  {'CustomerId': 15705512,
#   'CreditScore': 668,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 37,
#   'Tenure': 6,
#   'Balance': 167864.4,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 115638.29,
#   'Exited': 0},
#  {'CustomerId': 15698028,
#   'CreditScore': 506,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 41,
#   'Tenure': 1,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 31766.3,
#   'Exited': 0},
#  {'CustomerId': 15661670,
#   'CreditScore': 524,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 31,
#   'Tenure': 8,
#   'Balance': 107818.63,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 199725.39,
#   'Exited': 1},
#  {'CustomerId': 15600781,
#   'CreditScore': 699,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 34,
#   'Tenure': 4,
#   'Balance': 185173.81,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 120834.48,
#   'Exited': 0},
#  {'CustomerId': 15682472,
#   'CreditScore': 828,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 34,
#   'Tenure': 8,
#   'Balance': 129433.34,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 38131.77,
#   'Exited': 0},
#  {'CustomerId': 15580203,
#   'CreditScore': 674,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 39,
#   'Tenure': 6,
#   'Balance': 120193.42,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 100130.95,
#   'Exited': 0},
#  {'CustomerId': 15690673,
#   'CreditScore': 656,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 39,
#   'Tenure': 6,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 141069.88,
#   'Exited': 0},
#  {'CustomerId': 15760085,
#   'CreditScore': 684,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 48,
#   'Tenure': 10,
#   'Balance': 126384.42,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 198129.36,
#   'Exited': 0},
#  {'CustomerId': 15779659,
#   'CreditScore': 625,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 28,
#   'Tenure': 3,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 183646.41,
#   'Exited': 0},
#  {'CustomerId': 15627360,
#   'CreditScore': 432,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 42,
#   'Tenure': 9,
#   'Balance': 152603.45,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 110265.24,
#   'Exited': 1},
#  {'CustomerId': 15671137,
#   'CreditScore': 549,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 52,
#   'Tenure': 1,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 8636.05,
#   'Exited': 1},
#  {'CustomerId': 15782688,
#   'CreditScore': 625,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 56,
#   'Tenure': 0,
#   'Balance': 148507.24,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 46824.08,
#   'Exited': 1},
#  {'CustomerId': 15575492,
#   'CreditScore': 828,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 41,
#   'Tenure': 7,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 171378.77,
#   'Exited': 0},
#  {'CustomerId': 15591607,
#   'CreditScore': 770,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 24,
#   'Tenure': 9,
#   'Balance': 101827.07,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 167256.35,
#   'Exited': 0},
#  {'CustomerId': 15740404,
#   'CreditScore': 758,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 34,
#   'Tenure': 3,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 124226.16,
#   'Exited': 0},
#  {'CustomerId': 15718369,
#   'CreditScore': 795,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 33,
#   'Tenure': 9,
#   'Balance': 130862.43,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 114935.21,
#   'Exited': 0},
#  {'CustomerId': 15677871,
#   'CreditScore': 687,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 38,
#   'Tenure': 9,
#   'Balance': 122570.87,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 35608.88,
#   'Exited': 0},
#  {'CustomerId': 15642004,
#   'CreditScore': 686,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 25,
#   'Tenure': 1,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 16459.37,
#   'Exited': 0},
#  {'CustomerId': 15712543,
#   'CreditScore': 789,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 39,
#   'Tenure': 7,
#   'Balance': 124828.46,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 124411.08,
#   'Exited': 0},
#  {'CustomerId': 15584518,
#   'CreditScore': 589,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 50,
#   'Tenure': 5,
#   'Balance': 144895.05,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 34941.23,
#   'Exited': 0},
#  {'CustomerId': 15802381,
#   'CreditScore': 461,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 34,
#   'Tenure': 5,
#   'Balance': 63663.93,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 167784.28,
#   'Exited': 0},
#  {'CustomerId': 15610156,
#   'CreditScore': 637,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 40,
#   'Tenure': 2,
#   'Balance': 133463.1,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 93165.34,
#   'Exited': 0},
#  {'CustomerId': 15594408,
#   'CreditScore': 584,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 48,
#   'Tenure': 2,
#   'Balance': 213146.2,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 75161.25,
#   'Exited': 1},
#  {'CustomerId': 15640905,
#   'CreditScore': 579,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 35,
#   'Tenure': 1,
#   'Balance': 129490.36,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 8590.83,
#   'Exited': 1},
#  {'CustomerId': 15698932,
#   'CreditScore': 756,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 44,
#   'Tenure': 10,
#   'Balance': 137452.09,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 189543.9,
#   'Exited': 0},
#  {'CustomerId': 15724944,
#   'CreditScore': 663,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 34,
#   'Tenure': 7,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 180427.24,
#   'Exited': 0},
#  {'CustomerId': 15628145,
#   'CreditScore': 682,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 43,
#   'Tenure': 5,
#   'Balance': 125851.93,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 193318.33,
#   'Exited': 0},
#  {'CustomerId': 15713483,
#   'CreditScore': 793,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 52,
#   'Tenure': 2,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 159123.82,
#   'Exited': 1},
#  {'CustomerId': 15612350,
#   'CreditScore': 691,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 31,
#   'Tenure': 5,
#   'Balance': 40915.55,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 126213.84,
#   'Exited': 1},
#  {'CustomerId': 15800703,
#   'CreditScore': 485,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 21,
#   'Tenure': 5,
#   'Balance': 113157.22,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 54141.5,
#   'Exited': 0},
#  {'CustomerId': 15705707,
#   'CreditScore': 635,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 29,
#   'Tenure': 8,
#   'Balance': 138296.94,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 141075.51,
#   'Exited': 0},
#  {'CustomerId': 15754105,
#   'CreditScore': 650,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 37,
#   'Tenure': 5,
#   'Balance': 106967.18,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 24495.03,
#   'Exited': 0},
#  {'CustomerId': 15703264,
#   'CreditScore': 735,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 44,
#   'Tenure': 9,
#   'Balance': 120681.63,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 74836.34,
#   'Exited': 0},
#  {'CustomerId': 15794413,
#   'CreditScore': 416,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 32,
#   'Tenure': 0,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 878.87,
#   'Exited': 0},
#  {'CustomerId': 15650237,
#   'CreditScore': 754,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 32,
#   'Tenure': 7,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 89520.75,
#   'Exited': 0},
#  {'CustomerId': 15759618,
#   'CreditScore': 535,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 48,
#   'Tenure': 9,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 149892.79,
#   'Exited': 1},
#  {'CustomerId': 15811589,
#   'CreditScore': 716,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 42,
#   'Tenure': 8,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 180800.42,
#   'Exited': 0},
#  {'CustomerId': 15689044,
#   'CreditScore': 539,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 37,
#   'Tenure': 2,
#   'Balance': 127609.59,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 98646.22,
#   'Exited': 0},
#  {'CustomerId': 15709368,
#   'CreditScore': 614,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 43,
#   'Tenure': 6,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 109041.53,
#   'Exited': 0},
#  {'CustomerId': 15679145,
#   'CreditScore': 706,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 57,
#   'Tenure': 7,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 17941.16,
#   'Exited': 1},
#  {'CustomerId': 15655007,
#   'CreditScore': 758,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 33,
#   'Tenure': 7,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 82996.47,
#   'Exited': 0},
#  {'CustomerId': 15623595,
#   'CreditScore': 586,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 28,
#   'Tenure': 2,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 92067.35,
#   'Exited': 0},
#  {'CustomerId': 15589975,
#   'CreditScore': 646,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 73,
#   'Tenure': 6,
#   'Balance': 97259.25,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 104719.66,
#   'Exited': 0},
#  {'CustomerId': 15804017,
#   'CreditScore': 631,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 33,
#   'Tenure': 4,
#   'Balance': 123246.7,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 112687.57,
#   'Exited': 0},
#  {'CustomerId': 15692132,
#   'CreditScore': 717,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 22,
#   'Tenure': 6,
#   'Balance': 101060.25,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 84699.56,
#   'Exited': 0},
#  {'CustomerId': 15641122,
#   'CreditScore': 684,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 30,
#   'Tenure': 2,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 83473.82,
#   'Exited': 0},
#  {'CustomerId': 15630910,
#   'CreditScore': 800,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 49,
#   'Tenure': 7,
#   'Balance': 108007.36,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 47125.11,
#   'Exited': 0},
#  {'CustomerId': 15680772,
#   'CreditScore': 721,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 36,
#   'Tenure': 2,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 106977.8,
#   'Exited': 0},
#  {'CustomerId': 15658929,
#   'CreditScore': 683,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 29,
#   'Tenure': 0,
#   'Balance': 133702.89,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 55582.54,
#   'Exited': 1},
#  {'CustomerId': 15585388,
#   'CreditScore': 660,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 31,
#   'Tenure': 9,
#   'Balance': 125189.75,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 139874.43,
#   'Exited': 0},
#  {'CustomerId': 15724623,
#   'CreditScore': 704,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 24,
#   'Tenure': 7,
#   'Balance': 113034.22,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 162503.48,
#   'Exited': 1},
#  {'CustomerId': 15588537,
#   'CreditScore': 615,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 41,
#   'Tenure': 9,
#   'Balance': 109013.23,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 196499.96,
#   'Exited': 0},
#  {'CustomerId': 15574692,
#   'CreditScore': 667,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 39,
#   'Tenure': 2,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 40721.24,
#   'Exited': 1},
#  {'CustomerId': 15611325,
#   'CreditScore': 682,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 24,
#   'Tenure': 9,
#   'Balance': 57929.81,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 53134.3,
#   'Exited': 0},
#  {'CustomerId': 15587562,
#   'CreditScore': 484,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 29,
#   'Tenure': 4,
#   'Balance': 130114.39,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 164017.89,
#   'Exited': 0},
#  {'CustomerId': 15613172,
#   'CreditScore': 628,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 27,
#   'Tenure': 5,
#   'Balance': 95826.49,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 155996.96,
#   'Exited': 0},
#  {'CustomerId': 15651022,
#   'CreditScore': 480,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 44,
#   'Tenure': 10,
#   'Balance': 129608.57,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 5472.7,
#   'Exited': 1},
#  {'CustomerId': 15586310,
#   'CreditScore': 578,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 30,
#   'Tenure': 4,
#   'Balance': 169462.09,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 112187.11,
#   'Exited': 0},
#  {'CustomerId': 15625524,
#   'CreditScore': 512,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 40,
#   'Tenure': 5,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 146457.83,
#   'Exited': 0},
#  {'CustomerId': 15755209,
#   'CreditScore': 484,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 35,
#   'Tenure': 7,
#   'Balance': 133868.21,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 27286.1,
#   'Exited': 0},
#  {'CustomerId': 15645248,
#   'CreditScore': 510,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 30,
#   'Tenure': 0,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 130553.47,
#   'Exited': 0},
#  {'CustomerId': 15790355,
#   'CreditScore': 606,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 36,
#   'Tenure': 5,
#   'Balance': 190479.48,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 179351.89,
#   'Exited': 0},
#  {'CustomerId': 15762615,
#   'CreditScore': 597,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 40,
#   'Tenure': 8,
#   'Balance': 101993.12,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 94774.12,
#   'Exited': 0},
#  {'CustomerId': 15625426,
#   'CreditScore': 754,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 55,
#   'Tenure': 3,
#   'Balance': 161608.81,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 8080.85,
#   'Exited': 1},
#  {'CustomerId': 15716334,
#   'CreditScore': 850,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 45,
#   'Tenure': 2,
#   'Balance': 122311.21,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 19482.5,
#   'Exited': 0},
#  {'CustomerId': 15789669,
#   'CreditScore': 510,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 65,
#   'Tenure': 2,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 48071.61,
#   'Exited': 0},
#  {'CustomerId': 15621075,
#   'CreditScore': 778,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 45,
#   'Tenure': 1,
#   'Balance': 162150.42,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 174531.27,
#   'Exited': 0},
#  {'CustomerId': 15810845,
#   'CreditScore': 636,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 42,
#   'Tenure': 2,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 55470.78,
#   'Exited': 0},
#  {'CustomerId': 15719377,
#   'CreditScore': 804,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 50,
#   'Tenure': 4,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 8546.87,
#   'Exited': 1},
#  {'CustomerId': 15654506,
#   'CreditScore': 514,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 32,
#   'Tenure': 8,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 95857.18,
#   'Exited': 0},
#  {'CustomerId': 15771977,
#   'CreditScore': 730,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 39,
#   'Tenure': 1,
#   'Balance': 99010.67,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 194945.8,
#   'Exited': 0},
#  {'CustomerId': 15708710,
#   'CreditScore': 525,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 37,
#   'Tenure': 0,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 131521.72,
#   'Exited': 0},
#  {'CustomerId': 15726676,
#   'CreditScore': 616,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 30,
#   'Tenure': 5,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 196108.51,
#   'Exited': 0},
#  {'CustomerId': 15587421,
#   'CreditScore': 687,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 34,
#   'Tenure': 7,
#   'Balance': 111388.18,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 148564.76,
#   'Exited': 0},
#  {'CustomerId': 15726931,
#   'CreditScore': 715,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 41,
#   'Tenure': 8,
#   'Balance': 56214.85,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 92982.61,
#   'Exited': 1},
#  {'CustomerId': 15771086,
#   'CreditScore': 512,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 36,
#   'Tenure': 3,
#   'Balance': 84327.77,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 17675.36,
#   'Exited': 0},
#  {'CustomerId': 15756850,
#   'CreditScore': 479,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 40,
#   'Tenure': 1,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 114996.43,
#   'Exited': 0},
#  {'CustomerId': 15702741,
#   'CreditScore': 601,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 32,
#   'Tenure': 8,
#   'Balance': 93012.89,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 86957.42,
#   'Exited': 0},
#  {'CustomerId': 15679200,
#   'CreditScore': 580,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 29,
#   'Tenure': 9,
#   'Balance': 61710.44,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 128077.8,
#   'Exited': 0},
#  {'CustomerId': 15594815,
#   'CreditScore': 807,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 35,
#   'Tenure': 3,
#   'Balance': 174790.15,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 600.36,
#   'Exited': 0},
#  {'CustomerId': 15635905,
#   'CreditScore': 616,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 32,
#   'Tenure': 6,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 43001.46,
#   'Exited': 0},
#  {'CustomerId': 15777892,
#   'CreditScore': 721,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 37,
#   'Tenure': 3,
#   'Balance': 107720.64,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 158591.12,
#   'Exited': 0},
#  {'CustomerId': 15656176,
#   'CreditScore': 501,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 57,
#   'Tenure': 10,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 47847.19,
#   'Exited': 0},
#  {'CustomerId': 15811127,
#   'CreditScore': 521,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 35,
#   'Tenure': 6,
#   'Balance': 96423.84,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 10488.44,
#   'Exited': 0},
#  {'CustomerId': 15604482,
#   'CreditScore': 850,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 30,
#   'Tenure': 2,
#   'Balance': 141040.01,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 5978.2,
#   'Exited': 0},
#  {'CustomerId': 15622911,
#   'CreditScore': 759,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 42,
#   'Tenure': 4,
#   'Balance': 105420.18,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 121409.06,
#   'Exited': 0},
#  {'CustomerId': 15600974,
#   'CreditScore': 516,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 50,
#   'Tenure': 5,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 146145.93,
#   'Exited': 1},
#  {'CustomerId': 15727868,
#   'CreditScore': 711,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 38,
#   'Tenure': 2,
#   'Balance': 129022.06,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 14374.86,
#   'Exited': 1},
#  {'CustomerId': 15627801,
#   'CreditScore': 512,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 33,
#   'Tenure': 3,
#   'Balance': 176666.62,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 94670.77,
#   'Exited': 0},
#  {'CustomerId': 15773039,
#   'CreditScore': 550,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 37,
#   'Tenure': 3,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 179670.31,
#   'Exited': 0},
#  {'CustomerId': 15755262,
#   'CreditScore': 608,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 41,
#   'Tenure': 3,
#   'Balance': 89763.84,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 199304.74,
#   'Exited': 1},
#  {'CustomerId': 15679531,
#   'CreditScore': 618,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 34,
#   'Tenure': 5,
#   'Balance': 134954.53,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 151954.39,
#   'Exited': 0},
#  {'CustomerId': 15684181,
#   'CreditScore': 643,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 45,
#   'Tenure': 5,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 142513.5,
#   'Exited': 1},
#  {'CustomerId': 15612087,
#   'CreditScore': 671,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 45,
#   'Tenure': 2,
#   'Balance': 106376.85,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 158264.62,
#   'Exited': 0},
#  {'CustomerId': 15752047,
#   'CreditScore': 689,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 33,
#   'Tenure': 2,
#   'Balance': 161814.64,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 169381.9,
#   'Exited': 0},
#  {'CustomerId': 15624592,
#   'CreditScore': 603,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 31,
#   'Tenure': 8,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 169915.02,
#   'Exited': 0},
#  {'CustomerId': 15573152,
#   'CreditScore': 620,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 41,
#   'Tenure': 9,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 88852.47,
#   'Exited': 0},
#  {'CustomerId': 15594917,
#   'CreditScore': 676,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 34,
#   'Tenure': 1,
#   'Balance': 63095.01,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 40645.81,
#   'Exited': 0},
#  {'CustomerId': 15785542,
#   'CreditScore': 572,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 26,
#   'Tenure': 4,
#   'Balance': 118287.01,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 60427.3,
#   'Exited': 0},
#  {'CustomerId': 15723488,
#   'CreditScore': 668,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 47,
#   'Tenure': 7,
#   'Balance': 106854.21,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 157959.02,
#   'Exited': 1},
#  {'CustomerId': 15680920,
#   'CreditScore': 695,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 46,
#   'Tenure': 7,
#   'Balance': 49512.55,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 133007.34,
#   'Exited': 0},
#  {'CustomerId': 15786308,
#   'CreditScore': 730,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 33,
#   'Tenure': 9,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 176576.62,
#   'Exited': 0},
#  {'CustomerId': 15659366,
#   'CreditScore': 807,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 43,
#   'Tenure': 1,
#   'Balance': 105799.32,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 34888.04,
#   'Exited': 1},
#  {'CustomerId': 15774854,
#   'CreditScore': 592,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 54,
#   'Tenure': 8,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 28737.71,
#   'Exited': 1},
#  {'CustomerId': 15725311,
#   'CreditScore': 726,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 31,
#   'Tenure': 9,
#   'Balance': 114722.05,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 98178.57,
#   'Exited': 0},
#  {'CustomerId': 15787155,
#   'CreditScore': 514,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 30,
#   'Tenure': 7,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 125010.24,
#   'Exited': 0},
#  {'CustomerId': 15727829,
#   'CreditScore': 567,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 42,
#   'Tenure': 2,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 167984.61,
#   'Exited': 0},
#  {'CustomerId': 15733247,
#   'CreditScore': 850,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 33,
#   'Tenure': 10,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 4861.72,
#   'Exited': 1},
#  {'CustomerId': 15568748,
#   'CreditScore': 671,
#   'Geography': 'Germany',
#   'Gender': 'Male',
# ...
#   'Tenure': 1,
#   'Balance': 101609.01,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 447.73,
#   'Exited': 0},
#  {'CustomerId': 15628303,
#   'CreditScore': 738,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 35,
#   'Tenure': 3,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 15650.73,
#   'Exited': 0},
#  {'CustomerId': 15633461,
#   'CreditScore': 639,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 38,
#   'Tenure': 5,
#   'Balance': 130170.82,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 149599.62,
#   'Exited': 0},
#  {'CustomerId': 15677135,
#   'CreditScore': 520,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 61,
#   'Tenure': 8,
#   'Balance': 133802.29,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 90304.01,
#   'Exited': 0},
#  {'CustomerId': 15590876,
#   'CreditScore': 764,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 24,
#   'Tenure': 7,
#   'Balance': 106234.02,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 115676.38,
#   'Exited': 0},
#  {'CustomerId': 15790782,
#   'CreditScore': 661,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 39,
#   'Tenure': 6,
#   'Balance': 132628.98,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 38812.67,
#   'Exited': 0},
#  {'CustomerId': 15700476,
#   'CreditScore': 564,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 41,
#   'Tenure': 9,
#   'Balance': 103522.75,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 34338.21,
#   'Exited': 0},
#  {'CustomerId': 15634141,
#   'CreditScore': 708,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 42,
#   'Tenure': 8,
#   'Balance': 192390.52,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 823.36,
#   'Exited': 0},
#  {'CustomerId': 15737795,
#   'CreditScore': 512,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 36,
#   'Tenure': 1,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 135482.26,
#   'Exited': 1},
#  {'CustomerId': 15790299,
#   'CreditScore': 592,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 37,
#   'Tenure': 9,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 10656.89,
#   'Exited': 0},
#  {'CustomerId': 15675316,
#   'CreditScore': 619,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 38,
#   'Tenure': 3,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 116467.35,
#   'Exited': 0},
#  {'CustomerId': 15613630,
#   'CreditScore': 775,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 52,
#   'Tenure': 8,
#   'Balance': 109922.61,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 96823.32,
#   'Exited': 1},
#  {'CustomerId': 15662100,
#   'CreditScore': 850,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 44,
#   'Tenure': 5,
#   'Balance': 128605.32,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 171096.2,
#   'Exited': 0},
#  {'CustomerId': 15668032,
#   'CreditScore': 577,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 37,
#   'Tenure': 4,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 79881.39,
#   'Exited': 0},
#  {'CustomerId': 15599289,
#   'CreditScore': 724,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 37,
#   'Tenure': 10,
#   'Balance': 68598.56,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 157862.82,
#   'Exited': 0},
#  {'CustomerId': 15754084,
#   'CreditScore': 710,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 35,
#   'Tenure': 1,
#   'Balance': 106518.52,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 127951.81,
#   'Exited': 0},
#  {'CustomerId': 15676521,
#   'CreditScore': 696,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 31,
#   'Tenure': 8,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 191074.11,
#   'Exited': 0},
#  {'CustomerId': 15804586,
#   'CreditScore': 376,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 46,
#   'Tenure': 6,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 157333.69,
#   'Exited': 1},
#  {'CustomerId': 15781465,
#   'CreditScore': 675,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 29,
#   'Tenure': 8,
#   'Balance': 121326.42,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 133457.52,
#   'Exited': 0},
#  {'CustomerId': 15729362,
#   'CreditScore': 745,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 36,
#   'Tenure': 8,
#   'Balance': 67226.37,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 130789.6,
#   'Exited': 0},
#  {'CustomerId': 15709295,
#   'CreditScore': 697,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 25,
#   'Tenure': 5,
#   'Balance': 82931.85,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 128373.88,
#   'Exited': 0},
#  {'CustomerId': 15745324,
#   'CreditScore': 599,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 39,
#   'Tenure': 4,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 194273.2,
#   'Exited': 1},
#  {'CustomerId': 15741336,
#   'CreditScore': 715,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 38,
#   'Tenure': 5,
#   'Balance': 118590.41,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 5684.17,
#   'Exited': 1},
#  {'CustomerId': 15783659,
#   'CreditScore': 659,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 67,
#   'Tenure': 4,
#   'Balance': 145981.87,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 131043.2,
#   'Exited': 0},
#  {'CustomerId': 15620981,
#   'CreditScore': 684,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 48,
#   'Tenure': 3,
#   'Balance': 73309.38,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 21228.34,
#   'Exited': 1},
#  {'CustomerId': 15630328,
#   'CreditScore': 635,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 48,
#   'Tenure': 8,
#   'Balance': 130796.33,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 43250.3,
#   'Exited': 0},
#  {'CustomerId': 15785899,
#   'CreditScore': 789,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 33,
#   'Tenure': 8,
#   'Balance': 151607.56,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 4389.4,
#   'Exited': 0},
#  {'CustomerId': 15606149,
#   'CreditScore': 571,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 66,
#   'Tenure': 9,
#   'Balance': 111577.01,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 189271.9,
#   'Exited': 0},
#  {'CustomerId': 15671139,
#   'CreditScore': 694,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 39,
#   'Tenure': 0,
#   'Balance': 107042.74,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 102284.2,
#   'Exited': 0},
#  {'CustomerId': 15660429,
#   'CreditScore': 665,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 42,
#   'Tenure': 2,
#   'Balance': 156371.61,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 156774.94,
#   'Exited': 1},
#  {'CustomerId': 15571002,
#   'CreditScore': 706,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 44,
#   'Tenure': 4,
#   'Balance': 129605.99,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 69865.49,
#   'Exited': 0},
#  {'CustomerId': 15631681,
#   'CreditScore': 807,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 43,
#   'Tenure': 0,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 85523.24,
#   'Exited': 0},
#  {'CustomerId': 15731522,
#   'CreditScore': 771,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 67,
#   'Tenure': 8,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 51219.8,
#   'Exited': 0},
#  {'CustomerId': 15619529,
#   'CreditScore': 531,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 27,
#   'Tenure': 8,
#   'Balance': 132576.25,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 7222.92,
#   'Exited': 0},
#  {'CustomerId': 15628034,
#   'CreditScore': 629,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 37,
#   'Tenure': 6,
#   'Balance': 129101.3,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 23971.33,
#   'Exited': 0},
#  {'CustomerId': 15686164,
#   'CreditScore': 850,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 31,
#   'Tenure': 1,
#   'Balance': 108822.4,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 132173.31,
#   'Exited': 0},
#  {'CustomerId': 15582797,
#   'CreditScore': 685,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 35,
#   'Tenure': 4,
#   'Balance': 137948.51,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 113639.64,
#   'Exited': 0},
#  {'CustomerId': 15753831,
#   'CreditScore': 642,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 32,
#   'Tenure': 7,
#   'Balance': 100433.8,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 39768.59,
#   'Exited': 0},
#  {'CustomerId': 15731815,
#   'CreditScore': 529,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 63,
#   'Tenure': 4,
#   'Balance': 96134.11,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 108732.96,
#   'Exited': 1},
#  {'CustomerId': 15580956,
#   'CreditScore': 683,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 43,
#   'Tenure': 4,
#   'Balance': 115888.04,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 117349.19,
#   'Exited': 1},
#  {'CustomerId': 15602084,
#   'CreditScore': 663,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 42,
#   'Tenure': 5,
#   'Balance': 124626.07,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 78004.5,
#   'Exited': 0},
#  {'CustomerId': 15589805,
#   'CreditScore': 563,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 34,
#   'Tenure': 6,
#   'Balance': 139810.34,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 152417.79,
#   'Exited': 0},
#  {'CustomerId': 15720893,
#   'CreditScore': 637,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 34,
#   'Tenure': 9,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 26057.08,
#   'Exited': 0},
#  {'CustomerId': 15641009,
#   'CreditScore': 544,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 37,
#   'Tenure': 3,
#   'Balance': 84496.71,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 79972.09,
#   'Exited': 0},
#  {'CustomerId': 15605926,
#   'CreditScore': 649,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 70,
#   'Tenure': 9,
#   'Balance': 116854.71,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 107125.79,
#   'Exited': 0},
#  {'CustomerId': 15805955,
#   'CreditScore': 638,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 48,
#   'Tenure': 10,
#   'Balance': 138333.03,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 47679.14,
#   'Exited': 0},
#  {'CustomerId': 15801488,
#   'CreditScore': 723,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 25,
#   'Tenure': 3,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 134509.47,
#   'Exited': 0},
#  {'CustomerId': 15605918,
#   'CreditScore': 635,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 43,
#   'Tenure': 5,
#   'Balance': 78992.75,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 153265.31,
#   'Exited': 0},
#  {'CustomerId': 15779711,
#   'CreditScore': 750,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 38,
#   'Tenure': 7,
#   'Balance': 97257.41,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 179883.04,
#   'Exited': 0},
#  {'CustomerId': 15705620,
#   'CreditScore': 730,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 34,
#   'Tenure': 5,
#   'Balance': 122453.37,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 138882.98,
#   'Exited': 0},
#  {'CustomerId': 15685357,
#   'CreditScore': 750,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 36,
#   'Tenure': 8,
#   'Balance': 112940.07,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 9855.81,
#   'Exited': 0},
#  {'CustomerId': 15570060,
#   'CreditScore': 586,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 43,
#   'Tenure': 8,
#   'Balance': 132558.26,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 67046.83,
#   'Exited': 1},
#  {'CustomerId': 15582616,
#   'CreditScore': 520,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 38,
#   'Tenure': 4,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 56388.63,
#   'Exited': 0},
#  {'CustomerId': 15799515,
#   'CreditScore': 652,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 48,
#   'Tenure': 8,
#   'Balance': 133297.24,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 77764.37,
#   'Exited': 0},
#  {'CustomerId': 15642937,
#   'CreditScore': 550,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 46,
#   'Tenure': 7,
#   'Balance': 0.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 130590.35,
#   'Exited': 0},
#  {'CustomerId': 15624729,
#   'CreditScore': 594,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 27,
#   'Tenure': 0,
#   'Balance': 197041.8,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 151912.49,
#   'Exited': 0},
#  {'CustomerId': 15566156,
#   'CreditScore': 749,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 44,
#   'Tenure': 0,
#   'Balance': 71497.79,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 151083.8,
#   'Exited': 0},
#  {'CustomerId': 15792360,
#   'CreditScore': 668,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 32,
#   'Tenure': 7,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 777.37,
#   'Exited': 0},
#  {'CustomerId': 15807008,
#   'CreditScore': 614,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 35,
#   'Tenure': 6,
#   'Balance': 128100.28,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 69454.24,
#   'Exited': 1},
#  {'CustomerId': 15704770,
#   'CreditScore': 773,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 25,
#   'Tenure': 1,
#   'Balance': 124532.78,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 11723.57,
#   'Exited': 0},
#  {'CustomerId': 15756475,
#   'CreditScore': 551,
#   'Geography': 'Germany',
#   'Gender': 'Male',
#   'Age': 31,
#   'Tenure': 9,
#   'Balance': 82293.82,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 91565.25,
#   'Exited': 0},
#  {'CustomerId': 15655339,
#   'CreditScore': 566,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 36,
#   'Tenure': 1,
#   'Balance': 142120.91,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 79616.37,
#   'Exited': 0},
#  {'CustomerId': 15613749,
#   'CreditScore': 569,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 34,
#   'Tenure': 0,
#   'Balance': 151839.26,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 102299.81,
#   'Exited': 1},
#  {'CustomerId': 15664521,
#   'CreditScore': 659,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 31,
#   'Tenure': 7,
#   'Balance': 149620.88,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 104533.51,
#   'Exited': 0},
#  {'CustomerId': 15681206,
#   'CreditScore': 722,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 49,
#   'Tenure': 3,
#   'Balance': 168197.66,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 140765.57,
#   'Exited': 1},
#  {'CustomerId': 15745527,
#   'CreditScore': 655,
#   'Geography': 'France',
#   'Gender': 'Male',
#   'Age': 37,
#   'Tenure': 5,
#   'Balance': 93147.0,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 66214.13,
#   'Exited': 0},
#  {'CustomerId': 15806926,
#   'CreditScore': 615,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 35,
#   'Tenure': 2,
#   'Balance': 97440.02,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 139816.1,
#   'Exited': 0},
#  {'CustomerId': 15724563,
#   'CreditScore': 752,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 42,
#   'Tenure': 3,
#   'Balance': 65046.08,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 140139.28,
#   'Exited': 0},
#  {'CustomerId': 15782899,
#   'CreditScore': 661,
#   'Geography': 'Spain',
#   'Gender': 'Female',
#   'Age': 28,
#   'Tenure': 7,
#   'Balance': 95357.49,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 102297.15,
#   'Exited': 0},
#  {'CustomerId': 15623521,
#   'CreditScore': 838,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 43,
#   'Tenure': 9,
#   'Balance': 123105.88,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 145765.83,
#   'Exited': 0},
#  {'CustomerId': 15810218,
#   'CreditScore': 610,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 29,
#   'Tenure': 9,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 83912.24,
#   'Exited': 0},
#  {'CustomerId': 15645621,
#   'CreditScore': 811,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 44,
#   'Tenure': 3,
#   'Balance': 0.0,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 78439.73,
#   'Exited': 0},
#  {'CustomerId': 15608114,
#   'CreditScore': 587,
#   'Geography': 'Spain',
#   'Gender': 'Male',
#   'Age': 62,
#   'Tenure': 7,
#   'Balance': 121286.27,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 6776.92,
#   'Exited': 0},
#  {'CustomerId': 15659557,
#   'CreditScore': 811,
#   'Geography': 'Germany',
#   'Gender': 'Female',
#   'Age': 28,
#   'Tenure': 4,
#   'Balance': 167738.82,
#   'IsActiveMember': 1,
#   'EstimatedSalary': 9903.42,
#   'Exited': 0},
#  {'CustomerId': 15787772,
#   'CreditScore': 759,
#   'Geography': 'France',
#   'Gender': 'Female',
#   'Age': 38,
#   'Tenure': 1,
#   'Balance': 104091.29,
#   'IsActiveMember': 0,
#   'EstimatedSalary': 91561.91,
#   'Exited': 0},
#  ...]

# %%
ExitperRegion = defaultdict(int)
for d in dat:
    if d['Exited'] == 1:
        ExitperRegion[d['Geography']] += 1

# %%
ExitperRegion
# Out:
# defaultdict(int, {'France': 810, 'Spain': 413, 'Germany': 814})

# %%
import matplotlib.pyplot as plt
x = [i for i in ExitperRegion.keys()]
y = [ExitperRegion[i] for i in x]

# %%
plt.gca().set(xlabel = 'Countries', ylabel = 'No of Exits', Title = 'Exits Per Country')
plt.ylim(300, 830)
plt.bar(x, y, color = 'Orange')
# Out:
# <BarContainer object of 3 artists>

# %%
ExitbyGender =defaultdict(int)
for d in dat:
    if d['Exited'] == 1:
        ExitbyGender[d['Gender']] += 1

# %%
x = [i for i in ExitbyGender.keys()]
y = [ExitbyGender[i] for i in x]
plt.gca().set(xlabel = 'Gender', ylabel = 'No of Exits', Title = 'Exits Per Gender')
plt.ylim(800, 1200)
plt.bar(x, y, color = 'Navy',align = 'center')
# Out:
# <BarContainer object of 2 artists>

# %%
ActiveNonActiveExits = defaultdict(int)
for d in dat:
    if d['Exited'] == 1:
        ActiveNonActiveExits[d['IsActiveMember']] += 1

# %%
ActiveNonActiveExits
# Out:
# defaultdict(int, {1: 735, 0: 1302})

# %%
x = [i for i in ActiveNonActiveExits.keys()]
y = [ActiveNonActiveExits[i] for i in x]
plt.gca().set(xlabel = 'Active or not', ylabel = 'No of Exits', Title = 'Exits per Activity')
# plt.ylim(800, 1200)
plt.xticks(ticks = [1, 0], labels=['Active', 'Non-Active'])
plt.bar(x, y, color = 'Teal')
# Out:
# <BarContainer object of 2 artists>
